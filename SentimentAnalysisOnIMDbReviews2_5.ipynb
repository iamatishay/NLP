# %% [markdown]
# <a href="https://colab.research.google.com/github/iamatishay/NLP/blob/main/SentimentAnalysisOnIMDbReviews2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from sklearn import metrics
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from gensim import models
from gensim.models import word2vec
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from wordcloud import WordCloud,STOPWORDS
from numpy import nan
from bs4 import BeautifulSoup
from nltk.stem import WordNetLemmatizer
# Out:
# C:\Users\ATISHAY\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\Users\ATISHAY\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#dataset from link - https://www.kaggle.com/c/si650winter11/data , Format: 1|0 (tab) sentence , 100086 lines.
path = 'C:\\Users\\ATISHAY\\Desktop\\labeledTrainData.tsv'
data = pd.read_table(path,header=None,skiprows=1,names=['Sentiment','Review'])
X = data.Review
y = data.Sentiment

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25000 entries, 5814_8 to 8478_8
# Data columns (total 2 columns):
# Sentiment    25000 non-null int64
# Review       25000 non-null object
# dtypes: int64(1), object(1)
# memory usage: 585.9+ KB

# %%
Sentiment_words=[]
for Sentiment in data['Sentiment']:
    if Sentiment ==0:
        Sentiment_words.append('Negative')
    elif Sentiment == 1:
        Sentiment_words.append('Postive')

# %%
word_count=pd.value_counts(data['Sentiment'].values, sort=False)
word_count
# Out:
# 0    12500
# 1    12500
# dtype: int64

# %%
Index = [1,2]
plt.figure(figsize=(5,5))
plt.bar(Index,word_count,color = 'blue')
plt.xticks(Index,['negative','positive'],rotation=45)
plt.ylabel('word_count')
plt.xlabel('word')
plt.title('Count of Moods')
plt.bar(Index, word_count)

for a,b in zip(Index, word_count):
    plt.text(a, b, str(b) ,color='green', fontweight='bold')
plt.show()

# %%
def review_to_words(raw_review):
    review =raw_review
    review = re.sub('[^a-zA-Z]', ' ',review)
    review = review.lower()
    review = review.split()
    lemmatizer = WordNetLemmatizer()
    review = [lemmatizer.lemmatize(w) for w in review if not w in set(stopwords.words('english'))]
    return (' '.join(review))

# %%
positive=data[data['Sentiment']==1]

# %%
words = ' '.join(positive['Review'])
split_word = " ".join([word for word in words.split()])

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(split_word)

# %%
plt.figure(1,figsize=(13, 13))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
negative=data[data['Sentiment']==0]

# %%
words1 = ' '.join(negative['Review'])
split_word = " ".join([word for word in words1.split()])

# %%
wordcloud1 = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=3000,
                      height=2500
                     ).generate(split_word)

# %%
plt.figure(1,figsize=(13, 13))
plt.imshow(wordcloud1)
plt.axis('off')
plt.show()

# %%
pos=positive['Review']

# %%
vectorizer = CountVectorizer(analyzer = "word",
                             tokenizer = None,
                             preprocessor = None,
                             stop_words = STOPWORDS,
                             max_features = 2000)

# %%
pos_words = vectorizer.fit_transform(pos)

# %%
pos_words = pos_words.toarray()

# %%
pos= vectorizer.get_feature_names()

# %%
pos
# Out:
# ['000',
#  '10',
#  '100',
#  '11',
#  '12',
#  '15',
#  '20',
#  '30',
#  '40',
#  '50',
#  '60',
#  '70',
#  '70s',
#  '80',
#  '80s',
#  '90',
#  'ability',
#  'able',
#  'absolute',
#  'absolutely',
#  'academy',
#  'accent',
#  'accept',
#  'accident',
#  'according',
#  'accurate',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'actor',
#  'actors',
#  'actress',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'adam',
#  'adaptation',
#  'add',
#  'added',
#  'addition',
#  'adds',
#  'admit',
#  'adult',
#  'adults',
#  'adventure',
#  'adventures',
#  'affair',
#  'afraid',
#  'africa',
#  'african',
#  'age',
#  'agent',
#  'ages',
#  'ago',
#  'agree',
#  'ahead',
#  'air',
#  'al',
#  'alan',
#  'albert',
#  'alive',
#  'allen',
#  'allow',
#  'allowed',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amazing',
#  'america',
#  'american',
#  'americans',
#  'among',
#  'amount',
#  'amusing',
#  'andrews',
#  'andy',
#  'angel',
#  'anger',
#  'angry',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'anime',
#  'ann',
#  'anna',
#  'anne',
#  'annoying',
#  'another',
#  'answer',
#  'anthony',
#  'anti',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'apart',
#  'apartment',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appealing',
#  'appear',
#  'appearance',
#  'appeared',
#  'appears',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'appropriate',
#  'area',
#  'aren',
#  'army',
#  'around',
#  'art',
#  'arthur',
#  'artist',
#  'artistic',
#  'arts',
#  'aside',
#  'ask',
#  'asked',
#  'asks',
#  'aspect',
#  'aspects',
#  'atmosphere',
#  'attack',
#  'attempt',
#  'attempts',
#  'attention',
#  'attitude',
#  'attractive',
#  'audience',
#  'audiences',
#  'aunt',
#  'author',
#  'available',
#  'average',
#  'avoid',
#  'award',
#  'awards',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'baby',
#  'back',
#  'background',
#  'bad',
#  'ball',
#  'band',
#  'bar',
#  'barbara',
#  'barely',
#  'baseball',
#  'based',
#  'basic',
#  'basically',
#  'batman',
#  'battle',
#  'beat',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'became',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'behind',
#  'believable',
#  'believe',
#  'believes',
#  'ben',
#  'besides',
#  'best',
#  'better',
#  'beyond',
#  'big',
#  'bigger',
#  'biggest',
#  'bill',
#  'billy',
#  'bit',
#  'bits',
#  'bizarre',
#  'black',
#  'blind',
#  'blood',
#  'blue',
#  'bob',
#  'body',
#  'bond',
#  'book',
#  'books',
#  'bored',
#  'boring',
#  'born',
#  'boss',
#  'bottom',
#  'bought',
#  'bourne',
#  'box',
#  'boy',
#  'boyfriend',
#  'boys',
#  'br',
#  'brain',
#  'brave',
#  'break',
#  'breaking',
#  'breaks',
#  'breathtaking',
#  'brian',
#  'brief',
#  'brilliant',
#  'brilliantly',
#  'bring',
#  'brings',
#  'british',
#  'broadway',
#  'broken',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'bruce',
#  'brutal',
#  'buddy',
#  'budget',
#  'build',
#  'building',
#  'bunch',
#  'burns',
#  'business',
#  'buy',
#  'cable',
#  'cage',
#  'call',
#  'called',
#  'came',
#  'cameo',
#  'camera',
#  'camp',
#  'candy',
#  'captain',
#  'capture',
#  'captured',
#  'captures',
#  'car',
#  'care',
#  'career',
#  'carry',
#  'cartoon',
#  'case',
#  'cast',
#  'casting',
#  'castle',
#  'cat',
#  'catch',
#  'caught',
#  'cause',
#  'caused',
#  'center',
#  'central',
#  'century',
#  'certain',
#  'certainly',
#  'chan',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'channel',
#  'character',
#  'characters',
#  'charles',
#  'charlie',
#  'charm',
#  'charming',
#  'chase',
#  'che',
#  'cheap',
#  'check',
#  'cheesy',
#  'chemistry',
#  'chief',
#  'child',
#  'childhood',
#  'children',
#  'chilling',
#  'china',
#  'chinese',
#  'choice',
#  'chris',
#  'christmas',
#  'christopher',
#  'church',
#  'cinderella',
#  'cinema',
#  'cinematic',
#  'cinematography',
#  'city',
#  'class',
#  'classic',
#  'classics',
#  'clean',
#  'clear',
#  'clearly',
#  'clever',
#  'climax',
#  'close',
#  'closer',
#  'clothes',
#  'club',
#  'co',
#  'code',
#  'cold',
#  'collection',
#  'college',
#  'color',
#  'colors',
#  'columbo',
#  'combination',
#  'come',
#  'comedic',
#  'comedies',
#  'comedy',
#  'comes',
#  'comic',
#  'coming',
#  'comment',
#  'commentary',
#  'comments',
#  'common',
#  'community',
#  'company',
#  'compare',
#  'compared',
#  'compelling',
#  'complete',
#  'completely',
#  'complex',
#  'computer',
#  'concept',
#  'concerned',
#  'conclusion',
#  'conflict',
#  'confused',
#  'consider',
#  'considered',
#  'considering',
#  'constant',
#  'constantly',
#  'contains',
#  'contemporary',
#  'content',
#  'continue',
#  'continues',
#  'contrast',
#  'control',
#  'convincing',
#  'cool',
#  'cop',
#  'cops',
#  'copy',
#  'core',
#  'costumes',
#  'couldn',
#  'count',
#  'country',
#  'couple',
#  'course',
#  'court',
#  'cover',
#  'cowboy',
#  'crafted',
#  'crap',
#  'crazy',
#  'create',
#  'created',
#  'creates',
#  'creating',
#  'creative',
#  'credit',
#  'credits',
#  'creepy',
#  'crew',
#  'crime',
#  'criminal',
#  'critics',
#  'cross',
#  'crowd',
#  'cry',
#  'cult',
#  'culture',
#  'curious',
#  'current',
#  'cut',
#  'cute',
#  'dad',
#  'damn',
#  'dan',
#  'dance',
#  'dancing',
#  'dangerous',
#  'daniel',
#  'danny',
#  'dark',
#  'date',
#  'dated',
#  'daughter',
#  'daughters',
#  'david',
#  'davis',
#  'day',
#  'days',
#  'de',
#  'dead',
#  'deal',
#  'dealing',
#  'deals',
#  'death',
#  'debut',
#  'decade',
#  'decent',
#  'decide',
#  'decided',
#  'decides',
#  'decision',
#  'deep',
#  'deeply',
#  'definitely',
#  'delight',
#  'delightful',
#  'deliver',
#  'delivers',
#  'depicted',
#  'depth',
#  'describe',
#  'deserved',
#  'deserves',
#  'design',
#  'desire',
#  'desperate',
#  'despite',
#  'detail',
#  'details',
#  'detective',
#  'develop',
#  'developed',
#  'development',
#  'devil',
#  'dialog',
#  'dialogue',
#  'dick',
#  'didn',
#  'die',
#  'died',
#  'dies',
#  'difference',
#  'different',
#  'difficult',
#  'direct',
#  'directed',
#  'directing',
#  'direction',
#  'director',
#  'directors',
#  'dirty',
#  'disappointed',
#  'discover',
#  'discovered',
#  'discovers',
#  'disney',
#  'disturbing',
#  'doctor',
#  'documentary',
#  'doesn',
#  'dog',
#  'don',
#  'donald',
#  'done',
#  'door',
#  'double',
#  'doubt',
#  'douglas',
#  'dr',
#  'drama',
#  'dramatic',
#  'drawn',
#  'dream',
#  'dreams',
#  'dressed',
#  'drew',
#  'drive',
#  'driven',
#  'drug',
#  'drugs',
#  'due',
#  'dull',
#  'dvd',
#  'dying',
#  'earlier',
#  'early',
#  'earth',
#  'easily',
#  'easy',
#  'ed',
#  'eddie',
#  'edge',
#  'editing',
#  'effect',
#  'effective',
#  'effects',
#  'effort',
#  'efforts',
#  'eight',
#  'either',
#  'element',
#  'elements',
#  'else',
#  'elvira',
#  'emma',
#  'emotion',
#  'emotional',
#  'emotionally',
#  'emotions',
#  'end',
#  'ended',
#  'ending',
#  'ends',
#  'energy',
#  'engaging',
#  'england',
#  'english',
#  'enjoy',
#  'enjoyable',
#  'enjoyed',
#  'enough',
#  'entertaining',
#  'entertainment',
#  'entire',
#  'entirely',
#  'epic',
#  'episode',
#  'episodes',
#  'equally',
#  'era',
#  'eric',
#  'escape',
#  'especially',
#  'etc',
#  'europe',
#  'european',
#  'even',
#  'evening',
#  'event',
#  'events',
#  'eventually',
#  'ever',
#  'every',
#  'everybody',
#  'everyday',
#  'everyone',
#  'everything',
#  'evil',
#  'ex',
#  'exactly',
#  'example',
#  'excellent',
#  'except',
#  'exception',
#  'exciting',
#  'existence',
#  'expect',
#  'expectations',
#  'expected',
#  'expecting',
#  'experience',
#  'experiences',
#  'explain',
#  'extra',
#  'extraordinary',
#  'extreme',
#  'extremely',
#  'eye',
#  'eyes',
#  'fabulous',
#  'face',
#  'faces',
#  'fact',
#  'fair',
#  'fairly',
#  'fairy',
#  'faith',
#  'fall',
#  'falling',
#  'falls',
#  'fame',
#  'familiar',
#  'families',
#  'family',
#  'famous',
#  'fan',
#  'fans',
#  'fantastic',
#  'fantasy',
#  'far',
#  'fascinating',
#  'fashion',
#  'fast',
#  'fate',
#  'father',
#  'favorite',
#  'favorites',
#  'favourite',
#  'fear',
#  'feature',
#  'features',
#  'featuring',
#  'feel',
#  'feeling',
#  'feelings',
#  'feels',
#  'fell',
#  'fellow',
#  'felt',
#  'female',
#  'festival',
#  'fi',
#  'fiction',
#  'field',
#  'fight',
#  'fighting',
#  'fights',
#  'figure',
#  'filled',
#  'film',
#  'filmed',
#  'filming',
#  'filmmaker',
#  'filmmakers',
#  'films',
#  'final',
#  'finale',
#  'finally',
#  'find',
#  'finding',
#  'finds',
#  'fine',
#  'finest',
#  'finish',
#  'finished',
#  'fire',
#  'first',
#  'fit',
#  'fits',
#  'five',
#  'flat',
#  'flaws',
#  'flick',
#  'flicks',
#  'flying',
#  'flynn',
#  'focus',
#  'focuses',
#  'folks',
#  'follow',
#  'followed',
#  'following',
#  'follows',
#  'food',
#  'foot',
#  'footage',
#  'force',
#  'forced',
#  'forces',
#  'ford',
#  'foreign',
#  'forever',
#  'forget',
#  'forgotten',
#  'form',
#  'former',
#  'formula',
#  'forward',
#  'found',
#  'four',
#  'fox',
#  'frame',
#  'france',
#  'frank',
#  'fred',
#  'free',
#  'freedom',
#  'french',
#  'fresh',
#  'friend',
#  'friendly',
#  'friends',
#  'friendship',
#  'front',
#  'fu',
#  'full',
#  'fully',
#  'fun',
#  'funniest',
#  'funny',
#  'future',
#  'game',
#  'games',
#  'gang',
#  'gangster',
#  'gary',
#  'gave',
#  'gay',
#  'gem',
#  'gene',
#  'general',
#  'generally',
#  'generation',
#  'genius',
#  'genre',
#  'genuine',
#  'genuinely',
#  'george',
#  'german',
#  'germany',
#  'gets',
#  'getting',
#  'ghost',
#  'giant',
#  'girl',
#  'girlfriend',
#  'girls',
#  'give',
#  'given',
#  'gives',
#  'giving',
#  'glad',
#  'go',
#  'god',
#  'goes',
#  'going',
#  'gold',
#  'golden',
#  'gone',
#  'good',
#  'gordon',
#  'gore',
#  'gorgeous',
#  'got',
#  'gotten',
#  'government',
#  'grace',
#  'grade',
#  'grand',
#  'grant',
#  'graphic',
#  'great',
#  'greatest',
#  'green',
#  'grew',
#  'grim',
#  'gripping',
#  'gritty',
#  'ground',
#  'group',
#  'grow',
#  'growing',
#  'grown',
#  'guess',
#  'gun',
#  'guy',
#  'guys',
#  'hair',
#  'half',
#  'hall',
#  'halloween',
#  'hand',
#  'hands',
#  'handsome',
#  'happen',
#  'happened',
#  'happening',
#  'happens',
#  'happiness',
#  'happy',
#  'hard',
#  'hardly',
#  'harris',
#  'harry',
#  'hasn',
#  'hate',
#  'haunting',
#  'haven',
#  'head',
#  'hear',
#  'heard',
#  'heart',
#  'hearted',
#  'heaven',
#  'heavy',
#  'held',
#  'hell',
#  'help',
#  'helped',
#  'helps',
#  'henry',
#  'hero',
#  'heroes',
#  'heroine',
#  'hey',
#  'hidden',
#  'high',
#  'higher',
#  'highly',
#  'hilarious',
#  'historical',
#  'history',
#  'hit',
#  'hitchcock',
#  'hitler',
#  'hits',
#  'hoffman',
#  'hold',
#  'holds',
#  'hollywood',
#  'home',
#  'honest',
#  'honestly',
#  'hong',
#  'hope',
#  'horrible',
#  'horror',
#  'horse',
#  'hospital',
#  'hot',
#  'hotel',
#  'hour',
#  'hours',
#  'house',
#  'howard',
#  'however',
#  'huge',
#  'human',
#  'humanity',
#  'humans',
#  'humor',
#  'humorous',
#  'humour',
#  'hunt',
#  'hurt',
#  'husband',
#  'ice',
#  'idea',
#  'ideas',
#  'identity',
#  'ii',
#  'image',
#  'images',
#  'imagination',
#  'imagine',
#  'imdb',
#  'immediately',
#  'impact',
#  'important',
#  'impossible',
#  'impressed',
#  'impression',
#  'impressive',
#  'include',
#  'included',
#  'includes',
#  'including',
#  'incredible',
#  'incredibly',
#  'indeed',
#  'independent',
#  'indian',
#  'individual',
#  'industry',
#  'influence',
#  'information',
#  'inner',
#  'innocent',
#  'inside',
#  'inspired',
#  'instance',
#  'instead',
#  'intelligence',
#  'intelligent',
#  'intended',
#  'intense',
#  'interest',
#  'interested',
#  'interesting',
#  'international',
#  'intriguing',
#  'introduced',
#  'involved',
#  'involving',
#  'island',
#  'isn',
#  'issue',
#  'issues',
#  'italian',
#  'jack',
#  'jackie',
#  'jackson',
#  'james',
#  'jane',
#  'japan',
#  'japanese',
#  'jason',
#  'jean',
#  'jeff',
#  'jerry',
#  'jim',
#  'jimmy',
#  'joan',
#  'job',
#  'joe',
#  'john',
#  'johnny',
#  'joke',
#  'jokes',
#  'jones',
#  'joseph',
#  'journey',
#  'joy',
#  'jr',
#  'judge',
#  'jump',
#  'justice',
#  'kate',
#  'keaton',
#  'keep',
#  'keeping',
#  'keeps',
#  'kelly',
#  'kept',
#  'kevin',
#  'key',
#  'kick',
#  'kid',
#  'kids',
#  'kill',
#  'killed',
#  'killer',
#  'killers',
#  'killing',
#  'kills',
#  'kind',
#  'king',
#  'knew',
#  'know',
#  'knowing',
#  'knowledge',
#  'known',
#  'knows',
#  'kong',
#  'kung',
#  'la',
#  'lack',
#  'ladies',
#  'lady',
#  'land',
#  'language',
#  'large',
#  'last',
#  'late',
#  'later',
#  'latter',
#  'laugh',
#  'laughed',
#  'laughing',
#  'laughs',
#  'law',
#  'lead',
#  'leader',
#  'leading',
#  'leads',
#  'learn',
#  'learned',
#  ...]

# %%
print (pos_words.shape)
# Out:
# (12500, 2000)

# %%
dist = np.sum(pos_words, axis=0)
for tag, count in zip(pos, dist):
    print (tag,count)
# Out:
# 000 126
# 10 2324
# 100 221
# 11 252
# 12 178
# 15 204
# 20 298
# 30 248
# 40 199
# 50 214
# wife 1196
# wild 260
# will 5218
# william 391
# williams 195
# willing 175
# win 290
# wind 162
# winner 165
# winning 252
# wise 216
# wish 499
# wit 134
# witch 167
# within 455
# without 1671
# witness 127
# witty 193
# woman 1439
# women 860
# won 916
# wonder 386
# wonderful 1372
# wonderfully 287
# wondering 138
# woods 176
# word 371
# words 435
# work 2346
# worked 295
# working 463
# works 848
# world 2430
# worse 220
# worst 252
# worth 1221
# worthy 171
# wouldn 363
# wow 163
# write 215
# writer 522
# writers 244
# writing 524
# written 787
# wrong 668
# wrote 243
# yeah 133
# year 1297
# years 2756
# yes 731
# yet 1558
# york 513
# young 2343
# younger 302
# youth 173
# zombie 230

# %%
postive_new= pd.DataFrame(dist)

# %%
postive_new.columns=['word_count']

# %%
postive_new['word'] = pd.Series(pos, index=postive_new.index)

# %%
postive_new1=postive_new[['word','word_count']]

# %%
postive_new1.head()
# Out:
#   word  word_count
# 0  000         126
# 1   10        2324
# 2  100         221
# 3   11         252
# 4   12         178

# %%
top_30_words=postive_new1.sort_values(['word_count'],ascending=[0])

# %%
top_30_words.head(30)
# Out:
#             word  word_count
# 220           br       49235
# 652         film       20940
# 1172       movie       19078
# 1250         one       13657
# 762         good        7724
# 1678       story        6779
# 1793        time        6516
# 774        great        6419
# 1930        well        6411
# 1532         see        6027
# 73          also        5551
# 1433      really        5475
# 1946        will        5218
# 569         even        4964
# 669        first        4757
# 1178        much        4687
# 1295      people        4480
# 189         best        4320
# 1061        love        4302
# 1019        life        4203
# 1922         way        4037
# 1075        made        3823
# 657        films        3813
# 1092        many        3766
# 1845         two        3733
# 1776       think        3655
# 1173      movies        3587
# 289   characters        3559
# 288    character        3516
# 494          don        3485

# %%
#Using CountVectorizer to convert text into tokens/features.
#Tuned CountVectorizer (1_gram) to get appropriate features/tokens and then transformed to obtain input variable (document term matrix).
vect = CountVectorizer(stop_words='english', ngram_range = (1,2), max_df = .80, min_df = 4)
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1, test_size= 0.2)#Splitted training test with test size of 20%

# %%
#Using training data to transform text into counts of features for each message
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)
X_test_dtm = vect.transform(X_test)
#Tested models on test data and calculated accuracy of predictions below.

# %%
#Accuracy using Naive Bayes Model
NB = MultinomialNB()
NB.fit(X_train_dtm, y_train)
y_pred = NB.predict(X_test_dtm)
print('\nNaive Bayes')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Naive Bayes
# Accuracy Score: 87.1%
# Confusion Matrix:
# [[2181  322]
#  [ 323 2174]]

# %%
#Accuracy using Logistic Regression Model
LR = LogisticRegression()
LR.fit(X_train_dtm, y_train)
y_pred = LR.predict(X_test_dtm)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Logistic Regression
# Accuracy Score: 88.9%
# Confusion Matrix:
# [[2215  288]
#  [ 267 2230]]

# %%
#Accuracy using SVM Model
SVM = LinearSVC()
SVM.fit(X_train_dtm, y_train)
y_pred = SVM.predict(X_test_dtm)
print('\nSupport Vector Machine')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Support Vector Machine
# Accuracy Score: 87.72%
# Confusion Matrix:
# [[2187  316]
#  [ 298 2199]]

# %%
#Accuracy using KNN Model
KNN = KNeighborsClassifier(n_neighbors = 3)
KNN.fit(X_train_dtm, y_train)
y_pred = KNN.predict(X_test_dtm)
print('\nK Nearest Neighbors (NN = 3)')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# K Nearest Neighbors (NN = 3)
# Accuracy Score: 55.44%
# Confusion Matrix:
# [[1791  712]
#  [1516  981]]

# %%
#Used Naive Bayes model to observe the number of tokens (words) and the positivity/negativity associated with that word.
tokens_words = vect.get_feature_names()
print('\nAnalysis')
print('No. of tokens: ',len(tokens_words))
counts = NB.feature_count_
df_table = {'Token':tokens_words,'Negative': counts[0,:],'Positive': counts[1,:]}
tokens = pd.DataFrame(df_table, columns= ['Token','Positive','Negative'])
positives = len(tokens[tokens['Positive']>tokens['Negative']])
print('No. of positive tokens: ',positives)
print('No. of negative tokens: ',len(tokens_words)-positives)
# Out:
# Analysis
# No. of tokens:  86480
# No. of positive tokens:  40329
# No. of negative tokens:  46151

# %%
labels = 'Positive tokens', 'Negative Tokens'
sizes = [40329,46151]
colors = ['blue', 'yellow' ]
explode = (0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=120)

plt.axis('equal')
plt.show()

# %%
#no. of unique words in the data set.
print("Number of words: ")
print(len(numpy.unique(numpy.hstack(X))))
# Out:
# Number of words:
# 24904

# %% [markdown]
# we can get an idea of the total number of unique words in the dataset from the above

# %%
print("Review length: ")
result = [len(x) for x in X]
print("Mean %.2f words (%f)" % (numpy.mean(result), numpy.std(result)))
pyplot.boxplot(result)
pyplot.show()
#We can see that the average review has just 61.11 words with a standard deviation of just 76.705041 words.
# Out:
# Review length:
# Mean 1327.71 words (1005.219141)

# %%
#Check positivity/negativity of specific tokens
#Implemented searching of selected words in the pandas dataframe to analyse specific words in the feature sets

token_search = ['good']
print('\nSearch Results for token/s:',token_search)
print(tokens.loc[tokens['Token'].isin(token_search)])
# Out:
# Search Results for token/s: ['good']
#       Token  Positive  Negative
# 32794  good    6242.0    5965.0

# %%
#Analyse False Negatives (Actual: 1; Predicted: 0)(Predicted negative review for a positive review)
print(X_test[ y_pred < y_test ])
# Out:
# 2161_10     How many of us wish that we could throw away s...
# 4950_8      Knowing when to end a movie is just as importa...
# 668_7       I just watched \The Last Wave\" in my school's...
# 8689_7      Perfect cast for a few-person drama. Simon is ...
# 3388_7      NYC, 2022: The Greenhouse effect, vanished oce...
# 10257_8     what can i say about this film that hasnt alre...
# 7027_7      \Bye Bye Birdie\" isn't one of the best musica...
# 9193_10     It holds very true to the original manga of th...
# 7512_8      Firstly, I have heard great things about this ...
# 9619_10     OK so a 10 for a 2 1/2 star movie you ask?...w...
# 5135_10     Simply but imaginatively filmed studio-set per...
# 748_9       This is 2009 and this way underrated gem has l...
# 11284_8     When I was a kid it was Lex Barker's time as T...
# 6459_10     Back to the roots with \like it is in heaven\"...
# 11556_7     Jack Lemmon and Walter Matthau began and endin...
# 2250_8      This is a wonderful movie about the struggle o...
# 1211_7      I grew up on this movie and I can remember whe...
# 8007_7      This game is very addictive, I kept playing it...
# 1953_2     The first episode of this new show was on toda...
# 6541_4     60 minutes in the beautiful Christina Galbo tr...
# 10172_1    When I spotted that Noah Wyle and Ricky Schrod...
# 11926_1    i am rarely moved to make these kind of commen...
# 12179_2    Not even worth watching this tacky spoiler rui...
# 7313_1     I wasted 5.75 to see this crappy movie so I ju...
# 10711_4    The Minion is about... well, a minion. A serva...
# 1261_2     I'm a Jean Harlow fan, because she had star qu...
# 10452_1    I saw the 10p.m. showing and I must say that t...
# 12131_2    Kevin Spacey is very talented, but unfortunate...
# 3425_1     I'm going to spend as much time on this review...
# 3042_1     I'm allowed to write 1000 words about this fil...
# 1742_1     Well, maybe I'm just having a bad run with Hin...
# 9067_3     Although I had some hopes for this film, parti...
# 6226_1     I cringed all the way through this movie. Firs...
# 10800_1    What was the point of this movie? What was the...
# 6604_3     The first one was the best. The second one suc...
#                                  ...
# 9217_2     Yes, about the only thing this film is memorab...
# 12182_1    Well where do i start? i think it's very insul...
# 6313_4     Well it's not often that we in the UK have a f...
# 5849_2     Being a fan of silent films, I looked forward ...
# 9329_1     One of the worst movies I ever saw. My only th...
# 8481_4     The acting was horrible and they got both of t...
# 3635_3     Some good movies keep you in front of the TV, ...
# 5168_1     If you are going to attempt building tension i...
# 3003_2     We all know that countless duds have graced th...
# 9022_3     I gave this movie a 5 out of pure pity. My int...
# 6650_3     I think this would have been a much better fil...
# 12010_4    The acronymic \F.P.1\" stands for \"Floating P...
# 7143_2     This movie has some of the most awesome cars I...
# 4906_1     Well I don't know where to begin. Obviously th...
# 9033_4     It seems a shame that Greta Garbo ended her il...
# 3370_2     Just a dumb old movie. First Stanwyck's son ge...
# 5878_4     As the front cover says \The hamlet of our tim...
# 11014_1    This is the worst movie I've ever seen in my l...
# 627_2      Oh dear lord. This movie... It was horrible. I...
# 2869_1     Story goes like this, Netflix was late sending...
# 10613_3    The dancing was probably the ONLY watchable th...
# 5346_3     I had to watch this film because the plot was ...
# 4532_1     My husband and I bought the Old School Sesame ...
# 11775_2    Watching \Kroko\" I would have liked to leave ...
# 1686_1     Imagine that you are asked by your date what m...
# 10619_1    ...but a lousy film. As Maltin says this was C...
# 12256_4    Oh God, I must have seen this when I was only ...
# 4505_2     Memoirs of a Geisha is a beautifully filmed mo...
# 9662_4     I usually read reviews before I watch a movie....
# 11904_1    The End of Violence and certainly the Million ...
# Name: Review, Length: 712, dtype: object

# %%
Path="C:\\Users\\ATISHAY\\Desktop\\labeledTrainData.tsv"

# %%
import pandas as pd
import numpy as np
import nltk

import warnings #Using Python 2.7. There will be some version warnings that we don't need to see.
warnings.filterwarnings("ignore")

#from sklearn.externals import joblib #I will add this back in when I'm ready to pickle the data.

from nltk.corpus import stopwords
stopwords=set(stopwords.words('english'))

# %%
moviedata = pd.read_csv(Path, header=0, delimiter="\t", quoting=3)

# %%
moviedata[0:5]
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
moviedata.review[1000]
# Out:
# '"I watched this movie really late last night and usually if it\'s late then I\'m pretty forgiving of movies. Although I tried, I just could not stand this movie at all, it kept getting worse and worse as the movie went on. Although I know it\'s suppose to be a comedy but I didn\'t find it very funny. It was also an especially unrealistic, and jaded portrayal of rural life. In case this is what any of you think country life is like, it\'s definitely not. I do have to agree that some of the guy cast members were cute, but the french guy was really fake. I do have to agree that it tried to have a good lesson in the story, but overall my recommendation is that no one over 8 watch it, it\'s just too annoying."'

# %%
moviedata.groupby("sentiment").count()
# Out:
#               id  review
# sentiment
# 0          12500   12500
# 1          12500   12500

# %%
from sklearn.pipeline import Pipeline

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

from sklearn.cross_validation import train_test_split, cross_val_score #Note train_test_split has moved around depending on the Python version

from sklearn.linear_model import LogisticRegression
#from sklearn.naive_bayes import MultinomialNB, BernoulliNB
#from sklearn.linear_model import SGDClassifier
#from sklearn.svm import SVC, LinearSVC, NuSVC
#from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV

from sklearn.metrics import classification_report, confusion_matrix, roc_curve

# %%
X=moviedata['review']
y=moviedata['sentiment']

X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=0.3)

print("train length: ", len(X_train),
      "\ntest length: ", len(X_test),
      "\noverall length: ", len(y_train) + len(y_test))
# Out:
# train length:  17500
# test length:  7500
# overall length:  25000

# %%
pipeline = Pipeline([
    ('vec', CountVectorizer(stop_words=stopwords)),
    ('tfidf', TfidfTransformer()),
    ('classifier', LogisticRegression())
])


ngram_range=[(1,1),(1, 2),(1,3)] #single words, bigrams and trigrams
min_df=[2,3,4] #kick out words that occur in less than 3 or 4 documents
#max_df=[0.5,1] #kick out words occuring in more than half the documents or don't.
#use_idf=[True, False] #use idf as part of tfidf. This is boolean.
Cs = [1, 10, 20] #Regularisation paramater for the logistic regression
#alpha=[.1] #Smoothing if using multinomial bayes

params= dict(vec__ngram_range=ngram_range,
                              vec__min_df=min_df,
                              #vec__max_df=max_df,
                              #tfidf__use_idf=use_idf
                              #classifier__alpha=alpha
                              classifier__C=Cs)

#grid = GridSearchCV(pipeline, params,cv=2, scoring='accuracy')
rand = RandomizedSearchCV(pipeline, params, cv=5, scoring='accuracy', n_iter=8, )

rand.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=Pipeline(steps=[('vec', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words={'ours', 'un...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))]),
#           fit_params={}, iid=True, n_iter=8, n_jobs=1,
#           param_distributions={'classifier__C': [1, 10, 20], 'vec__min_df': [2, 3, 4], 'vec__ngram_range': [(1, 1), (1, 2), (1, 3)]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           scoring='accuracy', verbose=0)

# %%
rand.grid_scores_
# Out:
# [mean: 0.88349, std: 0.00296, params: {'vec__min_df': 4, 'classifier__C': 20, 'vec__ngram_range': (1, 1)},
#  mean: 0.89383, std: 0.00274, params: {'vec__min_df': 3, 'classifier__C': 20, 'vec__ngram_range': (1, 3)},
#  mean: 0.89354, std: 0.00197, params: {'vec__min_df': 4, 'classifier__C': 20, 'vec__ngram_range': (1, 2)},
#  mean: 0.88320, std: 0.00355, params: {'vec__min_df': 2, 'classifier__C': 1, 'vec__ngram_range': (1, 3)},
#  mean: 0.88606, std: 0.00297, params: {'vec__min_df': 3, 'classifier__C': 10, 'vec__ngram_range': (1, 1)},
#  mean: 0.89320, std: 0.00227, params: {'vec__min_df': 2, 'classifier__C': 10, 'vec__ngram_range': (1, 2)},
#  mean: 0.88331, std: 0.00352, params: {'vec__min_df': 2, 'classifier__C': 1, 'vec__ngram_range': (1, 2)},
#  mean: 0.88366, std: 0.00377, params: {'vec__min_df': 4, 'classifier__C': 1, 'vec__ngram_range': (1, 3)}]

# %%
print(rand.grid_scores_[0].parameters)
print(rand.grid_scores_[0].cv_validation_scores)
print(rand.grid_scores_[0].mean_validation_score*100,'%',sep='')
# Out:
# {'vec__min_df': 4, 'classifier__C': 20, 'vec__ngram_range': (1, 1)}
# [ 0.88231934  0.87914286  0.88771429  0.88257143  0.88568162]
# 88.34857142857143%

# %%
# examine the best model
print(rand.best_score_*100,'%',sep='')
print(rand.best_params_)
# Out:
# 89.38285714285715%
# {'vec__min_df': 3, 'classifier__C': 20, 'vec__ngram_range': (1, 3)}

# %%
predictions_test=rand.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions_test))
print("")
print(classification_report(y_test,predictions_test))
# Out:
# [[3338  403]
#  [ 341 3418]]
#
#              precision    recall  f1-score   support
#
#           0       0.91      0.89      0.90      3741
#           1       0.89      0.91      0.90      3759
#
# avg / total       0.90      0.90      0.90      7500

# %%
y_test_preds=rand.predict_proba(X_test)[:, 1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# histogram of predicted probabilities
plt.hist(y_test_preds, bins=100, color="blue")
plt.xlim(0, 1)
plt.title('Histogram of predicted probabilities')
plt.xlabel('Predicted probability of positive sentiment')
plt.ylabel('Frequency')

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_test_preds)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Film Classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
print(metrics.roc_auc_score(y_test, y_test_preds))
# Out:
# 0.963787453638

# %%
pipeline = Pipeline([
    ('vec', CountVectorizer(stop_words=stopwords)),
    ('tfidf', TfidfTransformer()),
    ('classifier', LogisticRegression())
])


ngram_range=[(1,1),(1, 2),(1,3)] #single words, bigrams and trigrams
min_df=[2,3,4] #kick out words that occur in less than 3 or 4 documents
#max_df=[0.5,1] #kick out words occuring in more than half the documents or don't.
#use_idf=[True, False] #use idf as part of tfidf. This is boolean.
Cs = [1, 10, 20] #Regularisation paramater for the logistic regression
#alpha=[.1] #Smoothing if using multinomial bayes

params= dict(vec__ngram_range=ngram_range,
                              vec__min_df=min_df,
                              #vec__max_df=max_df,
                              #tfidf__use_idf=use_idf
                              #classifier__alpha=alpha
                              classifier__C=Cs)

#grid = GridSearchCV(pipeline, params,cv=2, scoring='accuracy')
rand = RandomizedSearchCV(pipeline, params, cv=5, scoring='accuracy', n_iter=8, )

rand.fit(X,y)
X_dtm = rand.transform(X)
LR_complete = LogisticRegression()
LR_complete.fit(X_dtm, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#Input Review.... any custom review as input
print('\nTest a custom review message')
print('Enter review to be analysed: ', end=" ")
test = []
test.append(input())
test_dtm = rand.transform(test)
predLabel = LR_complete.predict(test_dtm)
tags = ['Negative','Positive']
# Out:
# Test a custom review message
# Enter review to be analysed:  this was not a good movie as it was too long and waste of money

# %%
#Display Output
print('The review is predicted',tags[predLabel[0]])
# Out:
# The review is predicted Negative

# %%
print('Comparison between Classifiers')
# Out:
# Comparison between Classifiers

# %%
print(__doc__)
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

h = .02  # step size in the mesh

names = ["KNearest Neighbors", "Linear SVM",
          "Logistic Regression" , "Naive Bayes"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    LogisticRegression(),
    GaussianNB()


    ]

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [make_moons(noise=0.3, random_state=0),
            make_circles(noise=0.2, factor=0.5, random_state=1),
            linearly_separable
            ]

figure = plt.figure(figsize=(27, 9))
i = 1
# iterate over datasets
for ds_cnt, ds in enumerate(datasets):
    # preprocess dataset, split into training and test part
    X, y = ds
    X = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.4, random_state=42)

    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
               edgecolors='k')
    # and testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6,
               edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max]x[y_min, y_max].
        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
        else:
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot also the training points
        ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
                   edgecolors='k')
        # and testing points
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   edgecolors='k', alpha=0.6)

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        if ds_cnt == 0:
            ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# Automatically created module for IPython interactive environment
